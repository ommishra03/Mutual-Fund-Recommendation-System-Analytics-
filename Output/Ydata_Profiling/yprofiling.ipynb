# %%
pip install ydata-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df1 = pd.read_excel(r"../Excel/mutual_funds.xlsx")

# %%
df2 = pd.read_excel(r"../Excel/mutual_funds_cleaned.xlsx")

# %%
df3 = pd.read_excel(r"../Excel/mutual_funds_original.xlsx")

# %%
prof = ProfileReport(df1)
prof.to_file(output_file = 'mutual_funds.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prof = ProfileReport(df2)
prof.to_file(output_file = 'mutual_funds_cleaned.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prof = ProfileReport(df3)
prof.to_file(output_file = 'mutual_funds_original.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
